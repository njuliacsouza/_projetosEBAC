# %% [markdown]
# # EBAC - Regressão II - regressão múltipla
#
# ## Tarefa I

# %% [markdown]
# #### Previsão de renda II
#
# Vamos continuar trabalhando com a base 'previsao_de_renda.csv', que é a base do seu próximo projeto. Vamos usar os recursos que vimos até aqui nesta base.
#
# |variavel|descrição|
# |-|-|
# |data_ref                | Data de referência de coleta das variáveis |
# |index                   | Código de identificação do cliente|
# |sexo                    | Sexo do cliente|
# |posse_de_veiculo        | Indica se o cliente possui veículo|
# |posse_de_imovel         | Indica se o cliente possui imóvel|
# |qtd_filhos              | Quantidade de filhos do cliente|
# |tipo_renda              | Tipo de renda do cliente|
# |educacao                | Grau de instrução do cliente|
# |estado_civil            | Estado civil do cliente|
# |tipo_residencia         | Tipo de residência do cliente (própria, alugada etc)|
# |idade                   | Idade do cliente|
# |tempo_emprego           | Tempo no emprego atual|
# |qt_pessoas_residencia   | Quantidade de pessoas que moram na residência|
# |renda                   | Renda em reais|

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('previsao_de_renda.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   data_ref               15000 non-null  object
#  1   id_cliente             15000 non-null  int64
#  2   sexo                   15000 non-null  object
#  3   posse_de_veiculo       15000 non-null  bool
#  4   posse_de_imovel        15000 non-null  bool
#  5   qtd_filhos             15000 non-null  int64
#  6   tipo_renda             15000 non-null  object
#  7   educacao               15000 non-null  object
#  8   estado_civil           15000 non-null  object
#  9   tipo_residencia        15000 non-null  object
#  10  idade                  15000 non-null  int64
#  11  tempo_emprego          12427 non-null  float64
#  12  qt_pessoas_residencia  15000 non-null  float64
#  13  renda                  15000 non-null  float64
# dtypes: bool(2), float64(3), int64(3), object(6)
# memory usage: 1.4+ MB

# %% [markdown]
# 1. Separe a base em treinamento e teste (25% para teste, 75% para treinamento).
# 2. Rode uma regularização *ridge* com alpha = [0, 0.001, 0.005, 0.01, 0.05, 0.1] e avalie o $R^2$ na base de testes. Qual o melhor modelo?
# 3. Faça o mesmo que no passo 2, com uma regressão *LASSO*. Qual método chega a um melhor resultado?
# 4. Rode um modelo *stepwise*. Avalie o $R^2$ na vase de testes. Qual o melhor resultado?
# 5. Compare os parâmetros e avalie eventuais diferenças. Qual modelo você acha o melhor de todos?
# 6. Partindo dos modelos que você ajustou, tente melhorar o $R^2$ na base de testes. Use a criatividade, veja se consegue inserir alguma transformação ou combinação de variáveis.
# 7. Ajuste uma árvore de regressão e veja se consegue um $R^2$ melhor com ela.

# %%
# 1
train, test = train_test_split(df, test_size=0.25)
print('Train:', train.shape)
print('Test:', test.shape)
# Out:
# Train: (11250, 14)
# Test: (3750, 14)

# %%
# 2
modelo = '''np.log(renda) ~ 
                               C(sexo, Treatment(0))
                               + C(educacao, Treatment(0))
                               + C(posse_de_imovel, Treatment(1))
                               + idade
                               + tempo_emprego
                               '''
md = smf.ols(modelo, data=test)
reg = md.fit_regularized(method='elastic_net', refit=True, L1_wt=0, alpha=0)
reg.params
# Out:
# array([2.08545808, 0.96107781, 0.01522994, 0.65492655, 0.85500828,
#        0.46562997, 0.32611789, 0.10749121, 0.04960419])

# %%
md = smf.ols(modelo, data=test)
reg = md.fit_regularized(method='elastic_net', refit=True, L1_wt=0, alpha=0.001)
reg.params
# Out:
# array([ 6.60952112,  0.83603805,  0.39514479,  0.44597157,  0.58298705,
#         0.47719247, -0.06889759,  0.01031127,  0.05959678])

# %%
md = smf.ols(modelo, data=test)
reg = md.fit_regularized(method='elastic_net', refit=True, L1_wt=0, alpha=0.005)
reg.params
# Out:
# array([ 5.54826488,  0.87733624,  0.30185143,  1.0347894 ,  1.18532553,
#         1.04122343, -0.01581489,  0.02070575,  0.05863732])

# %%
md = smf.ols(modelo, data=test)
reg = md.fit_regularized(method='elastic_net', refit=True, L1_wt=0, alpha=0.01)
reg.params
# Out:
# array([4.93734736, 0.91460589, 0.19179355, 1.16415661, 1.32615681,
#        1.12197577, 0.03895703, 0.03126411, 0.05768207])

# %%
md = smf.ols(modelo, data=test)
reg = md.fit_regularized(method='elastic_net', refit=True, L1_wt=0, alpha=0.05)
reg.params
# Out:
# array([3.00340897, 1.00521473, 0.03741119, 0.91493373, 1.11245013,
#        0.72275391, 0.25497457, 0.07995977, 0.05290298])

# %%
md = smf.ols(modelo, data=test)
reg = md.fit_regularized(method='elastic_net', refit=True, L1_wt=0, alpha=0.1)
reg.params
# Out:
# array([2.08545808, 0.96107781, 0.01522994, 0.65492655, 0.85500828,
#        0.46562997, 0.32611789, 0.10749121, 0.04960419])

# %%
# 3
md = smf.ols(modelo, data=test)
reg = md.fit_regularized(method='elastic_net', refit=True, L1_wt=1, alpha=0.001)
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(renda)   R-squared:                       0.366
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     255.9
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):          1.94e-301
# Time:                        09:29:37   Log-Likelihood:                -3365.9
# No. Observations:                3112   AIC:                             6748.
# Df Residuals:                    3105   BIC:                             6796.
# Df Model:                           7
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            7.3340      0.063    115.767      0.000       7.210       7.458
# C(sexo, Treatment(0))[T.M]                           0.8220      0.027     30.234      0.000       0.769       0.875
# C(educacao, Treatment(0))[T.Pós graduação]                0          0        nan        nan           0           0
# C(educacao, Treatment(0))[T.Secundário]             -0.1314      0.027     -4.890      0.000      -0.184      -0.079
# C(educacao, Treatment(0))[T.Superior completo]            0          0        nan        nan           0           0
# C(educacao, Treatment(0))[T.Superior incompleto]    -0.1127      0.064     -1.766      0.077      -0.238       0.012
# C(posse_de_imovel, Treatment(1))[T.False]           -0.0847      0.027     -3.121      0.002      -0.138      -0.032
# idade                                                0.0070      0.001      4.794      0.000       0.004       0.010
# tempo_emprego                                        0.0599      0.002     29.924      0.000       0.056       0.064
# ==============================================================================
# Omnibus:                        0.504   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.777   Jarque-Bera (JB):                0.439
# Skew:                          -0.013   Prob(JB):                        0.803
# Kurtosis:                       3.052   Cond. No.                     1.28e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
md = smf.ols(modelo, data=test)
reg = md.fit_regularized(method='elastic_net', refit=True, L1_wt=1, alpha=0.005)
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(renda)   R-squared:                       0.365
# Model:                            OLS   Adj. R-squared:                  0.364
# Method:                 Least Squares   F-statistic:                     297.8
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):          5.10e-302
# Time:                        09:29:53   Log-Likelihood:                -3367.5
# No. Observations:                3112   AIC:                             6749.
# Df Residuals:                    3106   BIC:                             6791.
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            7.3110      0.062    117.873      0.000       7.189       7.433
# C(sexo, Treatment(0))[T.M]                           0.8223      0.027     30.235      0.000       0.769       0.876
# C(educacao, Treatment(0))[T.Pós graduação]                0          0        nan        nan           0           0
# C(educacao, Treatment(0))[T.Secundário]             -0.1201      0.026     -4.600      0.000      -0.171      -0.069
# C(educacao, Treatment(0))[T.Superior completo]            0          0        nan        nan           0           0
# C(educacao, Treatment(0))[T.Superior incompleto]          0          0        nan        nan           0           0
# C(posse_de_imovel, Treatment(1))[T.False]           -0.0870      0.027     -3.208      0.001      -0.140      -0.034
# idade                                                0.0073      0.001      5.019      0.000       0.004       0.010
# tempo_emprego                                        0.0599      0.002     29.930      0.000       0.056       0.064
# ==============================================================================
# Omnibus:                        0.535   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.765   Jarque-Bera (JB):                0.469
# Skew:                          -0.013   Prob(JB):                        0.791
# Kurtosis:                       3.054   Cond. No.                     1.28e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
md = smf.ols(modelo, data=test)
reg = md.fit_regularized(method='elastic_net', refit=True, L1_wt=1, alpha=0.01)
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(renda)   R-squared:                       0.365
# Model:                            OLS   Adj. R-squared:                  0.364
# Method:                 Least Squares   F-statistic:                     297.8
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):          5.10e-302
# Time:                        09:29:58   Log-Likelihood:                -3367.5
# No. Observations:                3112   AIC:                             6749.
# Df Residuals:                    3106   BIC:                             6791.
# Df Model:                           6
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            7.3110      0.062    117.873      0.000       7.189       7.433
# C(sexo, Treatment(0))[T.M]                           0.8223      0.027     30.235      0.000       0.769       0.876
# C(educacao, Treatment(0))[T.Pós graduação]                0          0        nan        nan           0           0
# C(educacao, Treatment(0))[T.Secundário]             -0.1201      0.026     -4.600      0.000      -0.171      -0.069
# C(educacao, Treatment(0))[T.Superior completo]            0          0        nan        nan           0           0
# C(educacao, Treatment(0))[T.Superior incompleto]          0          0        nan        nan           0           0
# C(posse_de_imovel, Treatment(1))[T.False]           -0.0870      0.027     -3.208      0.001      -0.140      -0.034
# idade                                                0.0073      0.001      5.019      0.000       0.004       0.010
# tempo_emprego                                        0.0599      0.002     29.930      0.000       0.056       0.064
# ==============================================================================
# Omnibus:                        0.535   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.765   Jarque-Bera (JB):                0.469
# Skew:                          -0.013   Prob(JB):                        0.791
# Kurtosis:                       3.054   Cond. No.                     1.28e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
md = smf.ols(modelo, data=test)
reg = md.fit_regularized(method='elastic_net', refit=True, L1_wt=1, alpha=0.05)
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(renda)   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.358
# Method:                 Least Squares   F-statistic:                     434.7
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):          7.75e-298
# Time:                        09:30:04   Log-Likelihood:                -3383.2
# No. Observations:                3112   AIC:                             6776.
# Df Residuals:                    3108   BIC:                             6807.
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            7.2281      0.060    120.639      0.000       7.111       7.346
# C(sexo, Treatment(0))[T.M]                           0.8139      0.027     29.834      0.000       0.760       0.867
# C(educacao, Treatment(0))[T.Pós graduação]                0          0        nan        nan           0           0
# C(educacao, Treatment(0))[T.Secundário]                   0          0        nan        nan           0           0
# C(educacao, Treatment(0))[T.Superior completo]            0          0        nan        nan           0           0
# C(educacao, Treatment(0))[T.Superior incompleto]          0          0        nan        nan           0           0
# C(posse_de_imovel, Treatment(1))[T.False]                 0          0        nan        nan           0           0
# idade                                                0.0070      0.001      4.872      0.000       0.004       0.010
# tempo_emprego                                        0.0598      0.002     29.765      0.000       0.056       0.064
# ==============================================================================
# Omnibus:                        0.394   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.821   Jarque-Bera (JB):                0.336
# Skew:                          -0.015   Prob(JB):                        0.845
# Kurtosis:                       3.041   Cond. No.                     1.28e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
md = smf.ols(modelo, data=test)
reg = md.fit_regularized(method='elastic_net', refit=True, L1_wt=1, alpha=0.1)
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(renda)   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.358
# Method:                 Least Squares   F-statistic:                     434.7
# Date:                Tue, 20 Sep 2022   Prob (F-statistic):          7.75e-298
# Time:                        09:30:12   Log-Likelihood:                -3383.2
# No. Observations:                3112   AIC:                             6776.
# Df Residuals:                    3108   BIC:                             6807.
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            7.2281      0.060    120.639      0.000       7.111       7.346
# C(sexo, Treatment(0))[T.M]                           0.8139      0.027     29.834      0.000       0.760       0.867
# C(educacao, Treatment(0))[T.Pós graduação]                0          0        nan        nan           0           0
# C(educacao, Treatment(0))[T.Secundário]                   0          0        nan        nan           0           0
# C(educacao, Treatment(0))[T.Superior completo]            0          0        nan        nan           0           0
# C(educacao, Treatment(0))[T.Superior incompleto]          0          0        nan        nan           0           0
# C(posse_de_imovel, Treatment(1))[T.False]                 0          0        nan        nan           0           0
# idade                                                0.0070      0.001      4.872      0.000       0.004       0.010
# tempo_emprego                                        0.0598      0.002     29.765      0.000       0.056       0.064
# ==============================================================================
# Omnibus:                        0.394   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.821   Jarque-Bera (JB):                0.336
# Skew:                          -0.015   Prob(JB):                        0.845
# Kurtosis:                       3.041   Cond. No.                     1.28e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
