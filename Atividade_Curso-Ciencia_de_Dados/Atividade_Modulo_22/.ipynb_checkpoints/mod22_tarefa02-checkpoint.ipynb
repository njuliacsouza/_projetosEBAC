# %% [markdown]
# # Tarefa 02
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %%
import pandas as pd
import numpy as np

import plotly.express as px
from plotly import graph_objects

# %% [markdown]
# #### 1. Carregue os dados da tarefa anterior

# %%
data = pd.read_csv('yahoo_finance_data.csv', header=[0,1])
print(data.shape)
data.head()
# Out:
# (516, 18)
#   Adj Close                                 Close                              \
#       ^BVSP          ^DJI         ^IXIC     ^BVSP          ^DJI         ^IXIC
# 0  110335.0  31535.509766  13588.830078  110335.0  31535.509766  13588.830078
# 1  111540.0  31391.519531  13358.790039  111540.0  31391.519531  13358.790039
# 2  111184.0  31270.089844  12997.750000  111184.0  31270.089844  12997.750000
# 3  112690.0  30924.140625  12723.469727  112690.0  30924.140625  12723.469727
# 4  115202.0  31496.300781  12920.150391  115202.0  31496.300781  12920.150391
#
#        High                                   Low                              \
#       ^BVSP          ^DJI         ^IXIC     ^BVSP          ^DJI         ^IXIC
# 0  112445.0  31668.339844  13596.589844  110036.0  31065.900391  13362.660156
# 1  112428.0  31623.269531  13601.330078  107319.0  31377.160156  13352.000000
# 2  112398.0  31563.310547  13372.519531  107466.0  31260.140625  12995.070312
# 3  114433.0  31461.970703  13068.709961  111163.0  30547.529297  12553.959961
# 4  115504.0  31580.330078  12941.209961  112504.0  30766.810547  12397.049805
#
#        Open                                  Volume
#       ^BVSP          ^DJI         ^IXIC       ^BVSP         ^DJI         ^IXIC
# 0  110036.0  31065.900391  13406.160156  11239900.0  385670000.0  5.079530e+09
# 1  110328.0  31535.369141  13599.450195  14823200.0  337270000.0  4.948140e+09
# 2  111529.0  31352.960938  13336.250000  15144300.0  409660000.0  5.529980e+09
# 3  111191.0  31289.009766  12953.990234  14221600.0  537850000.0  7.864380e+09
# 4  112690.0  31029.179688  12860.040039  13254800.0  501810000.0  7.725200e+09

# %% [markdown]
# #### 2. Média móvel
#
# 1. Faça uma média móvel  em 90 dias dos valores de fechamento ajustados dos ativos que você escolheu
# 2. Utilizando a fução ```rolling()```, calcule o desvio pardão desses ativos ao longo do tempo, utilizando a mesma janela móvel do item acima
# 2. Monte um gráfico de linhas para as médias móveis dos ativos da sua base
# 4. Monte um gráfico de linhas para os desvios padrão em janela móvel
# 5. Compare os dois gráficos que você fez com o da tarefa anterior. Veja se eles apontam conclusões semelhantes quanto aos períodos de maior volatilidade (variação) dos ativos.

# %%
pip install numba

# %%
from numba import jit

# %%
data['Adj Close'].rolling(90, method='table').mean()

# %%
# 1. Faça uma média móvel em 90 dias dos valores de fechamento ajustados dos ativos que você escolheu

data['Adj Close'].rolling(90, method='table').mean()
df_media_movel_90
# Out:
#      ^BVSP  ^DJI  ^IXIC
# 0      NaN   NaN    NaN
# 1      NaN   NaN    NaN
# 2      NaN   NaN    NaN
# 3      NaN   NaN    NaN
# 4      NaN   NaN    NaN
# ..     ...   ...    ...
# 511    NaN   NaN    NaN
# 512    NaN   NaN    NaN
# 513    NaN   NaN    NaN
# 514    NaN   NaN    NaN
# 515    NaN   NaN    NaN
#
# [516 rows x 3 columns]

# %% [markdown]
# #### 3. Gráfico de *candlestick*
# 1. Selecione o período dos últimos 60 dias (corridos) para um dos ativos da sua base
# 2. Monte um gráfico de *candlestick* para esses dados.
